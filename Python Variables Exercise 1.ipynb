# %% [markdown]
# Exercise 1: The Bio Builder (Warm-up)
# Goal: Create variables of different data types and print them.
#
# Create a variable named first_name and assign your name to it.
#
# Create a variable named age and assign your age to it (as an integer).
#
# Create a variable named is_student and set it to either True or False.
#
# Print each variable on a new line.

# %%
# %python
first_name="Diana"

# %%
print(first_name)

# %%
age=25

# %%
print(age)

# %%
is_student= "True"

# %%
print(is_student)

# %% [markdown]
# Exercise 2: The Swapper 🔄
# Goal: Swap the values of two variables.
#
# Start with these two variables:
# a=10
# b=50
#
# Write code that swaps their values so that a becomes 50 and b becomes 10.
#
# Challenge: Try to do this in just one line of code (the Pythonic way)!

# %%
a=10
b=50

#swap values
a,b=b,a
print(a,b)

# %% [markdown]
# Exercise 3: Math with Variables 🧮
# Goal: Use variables to perform calculations.
#
# Create a variable length and set it to 15.
#
# Create a variable width and set it to 8.
#
# Create a third variable called area and calculate the area of a rectangle using the length and width variables.
#
# Print a message that says: "The area of the rectangle is [value of area]".

# %%
length=15

# %%
print(length)

# %%
width=8

# %%
print(width)

# %%
area=length * width
print(area)

# %%
print("The area of the rectangle is", area)

# %% [markdown]
# Exercise 4: The Dynamic Counter 📈
# Goal: Update a variable's value over time.
#
# Create a variable called score and initialize it to 0.
#
# The player just defeated a monster! Increase the score by 100 points.
#
# The player found a secret coin! Increase the score by another 50 points.
#
# The player bumped into a spike. Decrease the score by 25 points.
#
# Print the final score. (Hint: Use shorthand operators like += and -=).

# %%
score=0
score+=100
score+=100
score-=25
print(score)

# %% [markdown]
# Exercise 5: The Fixer-Upper (Debugging) 🛠️
# Goal: Find and fix the illegal variable names.
# The following code block has three broken variable names that will cause Python to throw a SyntaxError

# %%
# Fix this code!
1st_place_prize = "Gold Medal"
total-$_spent = 45.50
class = "Introduction to Python"

print(1st_place_prize)
print(total-$_spent)
print(class)

# %%
_first_place_prize = "Gold Medal"
total_money_spent = 45.50
_class = "Introduction to Python"

print(_first_place_prize)
print(total_money_spent)
print(_class)
